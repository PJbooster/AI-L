# %% [markdown]
# # Analiza i Przewidywanie Trendów Giełdowych: Allegro (ALE.WA)
# Ten notebook przedstawia proces budowy modelu Machine Learning do klasyfikacji kierunku zmian cen akcji.
# **Etapy:**
# 1. Pobieranie danych (yFinance)
# 2. Inżynieria cech (Wskaźniki techniczne)
# 3. Przygotowanie danych do modelu (Scaling & Splitting)
# 4. Trenowanie modelu Random Forest

# %%
import yfinance as yf
import pandas as pd
import plotly.graph_objects as go

# Pobieramy dane
ticker = "ALE.WA"
df = yf.download(ticker, start="2022-01-01")

# 2. Feature Engineering (Inżynieria cech)
df['MA20'] = df['Close'].rolling(window=20).mean()
df['MA50'] = df['Close'].rolling(window=50).mean()
df['Return'] = df['Close'].pct_change()
# Target: 1 jeśli jutro cena wzrośnie, 0 jeśli spadnie
df['Target'] = (df['Close'].shift(-1) > df['Close']).astype(int)

# Czyszczenie danych z wartości pustych (NaN)
df = df.dropna()

df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open   Volume     MA20  \
# Ticker         ALE.WA     ALE.WA     ALE.WA     ALE.WA   ALE.WA
# Date
# 2022-03-14  29.240000  29.674999  28.360001  29.250000  2381598  29.9705
# 2022-03-15  29.430000  29.959999  28.410000  29.799999  2522757  29.6575
# 2022-03-16  30.895000  32.200001  30.120001  30.969999  4645894  29.4860
# 2022-03-17  32.700001  32.700001  31.200001  31.850000  5821212  29.4295
# 2022-03-18  32.430000  33.150002  31.945000  32.939999  4973978  29.4185
#
# Price          MA50    Return Target
# Ticker
# Date
# 2022-03-14  34.9022 -0.004426      1
# 2022-03-15  34.7028  0.006498      1
# 2022-03-16  34.5451  0.049779      1
# 2022-03-17  34.4434  0.058424      0
# 2022-03-18  34.3047 -0.008257      0
